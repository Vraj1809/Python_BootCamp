# %%
# getting the current working directory
pwd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # getting the current working directory
# ----> 2 pwd
#
# NameError: name 'pwd' is not defined

# %%
# but it would only work in the command pormpt and that also with some operating systems

import os

print("Getting the current working directory:\n")
print(os.getcwd())

print("\nGetting the lists of files in the directory:")
print(os.listdir())

# can also give the directory as the argument
print(os.listdir("C:\\Users\\VrajDesai\\Desktop\\ML_AI_Course\\Python_BootCamp"))
# Out:
# Getting the current working directory:
#
# c:\Users\VrajDesai\Desktop\ML_AI_Course\Python_BootCamp\Advanced Python Modules
#
# Getting the lists of files in the directory:
# ['collection_module.ipynb', 'shutil_OS_modules.ipynb']
# ['.git', 'Advanced Python Modules', 'Decorators', 'Error_and_Exceptions_Handling', 'Generator', 'MileStone_Project_1', 'Milestone_Project_2', 'Modules_Packages', 'OOPs', 'Python_Method_Function', 'Python_Object_&_Data_Structures', 'Python_Statements', 'README.md']

# %%
#Moving Files

import shutil

print("Folder Structure Before Moving:")
print(os.listdir())

shutil.move('test.txt','C:\\Users\\VrajDesai\\Desktop\\ML_AI_Course\\Python_BootCamp')

print("Folder Structure After Moving:")
print(os.listdir())
# Out:
# Folder Structure Before Moving:
# ['collection_module.ipynb', 'shutil_OS_modules.ipynb', 'test.txt']
# Folder Structure After Moving:
# ['collection_module.ipynb', 'shutil_OS_modules.ipynb']

# %% [markdown]
# NOTE: The os module provides 3 methods for deleting files:
#
# os.unlink(path) which deletes a file at the path your provide
# os.rmdir(path) which deletes a folder (folder must be empty) at the path your provide
# shutil.rmtree(path) this is the most dangerous, as it will remove all files and folders contained in the path. All of these methods can not be reversed! Which means if you make a mistake you won't be able to recover the file. Instead we will use the send2trash module. A safer alternative that sends deleted files to the trash bin instead of permanent removal.

# %%
# safer option - send2trash module
import send2trash

print("Folder Structure Before Moving:")
print(os.listdir("C:\\Users\\VrajDesai\\Desktop\\ML_AI_Course\\Python_BootCamp"))

send2trash.send2trash("C:\\Users\\VrajDesai\\Desktop\\ML_AI_Course\\Python_BootCamp\\test.txt")

print("Folder Structure After Moving:")
print(os.listdir("C:\\Users\\VrajDesai\\Desktop\\ML_AI_Course\\Python_BootCamp"))
# Out:
# Folder Structure Before Moving:
# ['.git', 'Advanced Python Modules', 'Decorators', 'Error_and_Exceptions_Handling', 'Generator', 'MileStone_Project_1', 'Milestone_Project_2', 'Modules_Packages', 'OOPs', 'Python_Method_Function', 'Python_Object_&_Data_Structures', 'Python_Statements', 'README.md', 'test.txt']
# Folder Structure After Moving:
# ['.git', 'Advanced Python Modules', 'Decorators', 'Error_and_Exceptions_Handling', 'Generator', 'MileStone_Project_1', 'Milestone_Project_2', 'Modules_Packages', 'OOPs', 'Python_Method_Function', 'Python_Object_&_Data_Structures', 'Python_Statements', 'README.md']

# %%
for folder, sub_folder, files in os.walk("C:\\Users\\VrajDesai\\Desktop\\ML_AI_Course\\Python_BootCamp"):
    print(f"Currently in the folder: {folder}\n")
    print("The Sub-folders are:")
    for sub_folder in sub_folder:
        print(f"\t Sub-folder: {sub_folder}")
    
    print('\n')
    
    print("The Files are:")
    for file in files:
        print(f"\t File: {file}")
    print("\n")
# Out:
# Currently in the folder: C:\Users\VrajDesai\Desktop\ML_AI_Course\Python_BootCamp
#
# The Sub-folders are:
# 	 Sub-folder: .git
# 	 Sub-folder: Advanced Python Modules
# 	 Sub-folder: Decorators
# 	 Sub-folder: Error_and_Exceptions_Handling
# 	 Sub-folder: Generator
# 	 Sub-folder: MileStone_Project_1
# 	 Sub-folder: Milestone_Project_2
# 	 Sub-folder: Modules_Packages
# 	 Sub-folder: OOPs
# 	 Sub-folder: Python_Method_Function
# 	 Sub-folder: Python_Object_&_Data_Structures
# 	 Sub-folder: Python_Statements
#
#
# The Files are:
# 	 File: README.md
#
#
# Currently in the folder: C:\Users\VrajDesai\Desktop\ML_AI_Course\Python_BootCamp\.git
#
# The Sub-folders are:
# 	 Sub-folder: hooks
# 	 Sub-folder: info
# 	 Sub-folder: logs
# 	 Sub-folder: objects
# 	 Sub-folder: refs
#
#
# The Files are:
# 	 File: COMMIT_EDITMSG
# 	 File: config
# 	 File: description
# 	 File: FETCH_HEAD
# 	 File: HEAD
# 	 File: index
# 	 File: ORIG_HEAD
# 	 File: packed-refs
#
#
# ...
